# %%
from langchain.output_parsers import StructuredOutputParser, ResponseSchema
from langchain.prompts import ChatPromptTemplate, HumanMessagePromptTemplate
from langchain.llms import OpenAI
from langchain.chat_models import ChatOpenAI
import pandas as pd
import json

# %%
openai_api_key = 'INSERT YOUR API KEY HERE'

# %%
# Temp = 0 so that we get clean information without a lot of creativity
chat_model = ChatOpenAI(temperature=0, openai_api_key=openai_api_key, max_tokens=1000)

# %%
# How you would like your response structured. This is basically a fancy prompt template
response_schemas = [
    ResponseSchema(name="opportunity_skills",
    description="These are the hard and soft skills you extract from the job_description"),
]

# How you would like to parse your output
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# %%
# See the prompt template you created for formatting
format_instructions = output_parser.get_format_instructions()
print (output_parser.get_format_instructions())
# Out:
# The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":
#
# ```json
# {
# 	"opportunity_skills": string  // These are the hard and soft skills you extract from the job_description
# }
# ```

# %%
template = """
You will be given a job description for the role of {opportunity_title}.
Your job is to extract soft and hard skills from the job description.

{format_instructions}

Wrap your final output with closed and open brackets (a list of json objects)

input_opportunity_description INPUT:
{opportunity_description}

YOUR RESPONSE:
"""

prompt = ChatPromptTemplate(
    messages=[
        HumanMessagePromptTemplate.from_template(template)  
    ],
    input_variables=["opportunity_title", "opportunity_description"],
    partial_variables={"format_instructions": format_instructions}
)

# %% [markdown]
# ### Load in the data

# %%
# Load the data
applications = pd.read_pickle("../../Data/split_4_enriched.pkl")

# %%
opportunity_id_sample = ['+5os8/vB/EGBEahyGxRMjA==',
'+0cRKl9xvkGTQq4D8IwnAQ==',
'+3lu6kPHC06xU79BvlwHew==',
'zu77vbq9g0ed54tWutsAig==',
'zsFZ88cMtUKMWf2kIKdncQ==',
'Pw9q3TmWDE6up1oUsv/OTA==',
'pJtXynDm6kqbyczn0dXkDg==',
'VPpkoLNRtUCOxpYUssltxg==',
'7uXMjQV9r061ap/Lc91I1Q==',
'Im/cVgG09Uesn1fjkbt5TQ==',]

# %%
# locate applications where the opportunity_id is in the sample
applications_sample = applications[applications.opportunity_id.isin(opportunity_id_sample)]
applications_sample
# Out:
#                  opportunity_id            application_id  \
# 580    Pw9q3TmWDE6up1oUsv/OTA==  jiJ1JAa/AkWkg853IcV99A==
# 688    Pw9q3TmWDE6up1oUsv/OTA==  DMMShh6ksEeTDMTqbqS5Nw==
# 1047   Pw9q3TmWDE6up1oUsv/OTA==  UUO4CGKds0SR5OdxnONVag==
# 1480   7uXMjQV9r061ap/Lc91I1Q==  i2GfHI8PiE2iSfMDmjNh3Q==
# 1901   Pw9q3TmWDE6up1oUsv/OTA==  wuHbCd1jAkSVhHG44qUcBg==
# ...                         ...                       ...
# 22014  +3lu6kPHC06xU79BvlwHew==  o9zE84ts7EeTJ16L/Et5AQ==
# 22015  +3lu6kPHC06xU79BvlwHew==  VinkkPxps0ulKfwNA9qOeQ==
# 22016  +3lu6kPHC06xU79BvlwHew==  PN7h+ikMHEKaJ/lKkTOYjg==
# 22017  +3lu6kPHC06xU79BvlwHew==  58O63nAFEkSn6PEFm63C4g==
# 22018  +3lu6kPHC06xU79BvlwHew==  ogoMXwf8hkKmTzUBjfLFgA==
#
#                            opportunity_brief_description  \
# 580    orkin purpose help protect world live work pla...
# 688    orkin purpose help protect world live work pla...
# 1047   orkin purpose help protect world live work pla...
# 1480   orkin purpose help protect world live work pla...
# 1901   orkin purpose help protect world live work pla...
# ...                                                  ...
# 22014  orkin purpose help protect world live work pla...
# 22015  orkin purpose help protect world live work pla...
# 22016  orkin purpose help protect world live work pla...
# 22017  orkin purpose help protect world live work pla...
# 22018  orkin purpose help protect world live work pla...
#
#                                  opportunity_description  \
# 580    orkin purpose help protect world live work pla...
# 688    orkin purpose help protect world live work pla...
# 1047   orkin purpose help protect world live work pla...
# 1480   orkin purpose help protect world live work pla...
# 1901   orkin purpose help protect world live work pla...
# ...                                                  ...
# 22014  orkin purpose help protect world live work pla...
# 22015  orkin purpose help protect world live work pla...
# 22016  orkin purpose help protect world live work pla...
# 22017  orkin purpose help protect world live work pla...
# 22018  orkin purpose help protect world live work pla...
#
#                                   opportunity_title  \
# 580                              termite technician
# 688                              termite technician
# 1047                             termite technician
# 1480   commercial sale representative hunter needed
# 1901                             termite technician
# ...                                             ...
# 22014                  customer relation specialist
# 22015                  customer relation specialist
# 22016                  customer relation specialist
# 22017                  customer relation specialist
# 22018                  customer relation specialist
#
#       application_pass_first_step application_step_category  \
# 580                         False                         0
# 688                         False                         0
# 1047                         True                         0
# 1480                         True                         0
# 1901                        False                         0
# ...                           ...                       ...
# 22014                       False                         0
# 22015                       False                         0
# 22016                       False                         0
# 22017                       False                         0
# 22018                       False                         0
#
#                                   application_job_titles  \
# 580    detention officer order builder administrative...
# 688             construction superintendent part manager
# 1047                                             laborer
# 1480   president bdm sale manager area sale manager t...
# 1901                         threat reduction specialist
# ...                                                  ...
# 22014  quality control technician laboratory technici...
# 22015                                            manager
# 22016  fraud detection coordinator assistant manager ...
# 22017                         compliance service analyst
# 22018  office assistant inbound sale executive telema...
#
#                         application_job_responsibilities  \
# 580    managed daily administrative operation departm...
# 688    osha 10 30 hour certification 15 year general ...
# 1047                         currently floor maintenance
# 1480   design develop implement national sale marketi...
# 1901   completed 4 year contract united state marine ...
# ...                                                  ...
# 22014  perform release product product hold analysis ...
# 22015  accounting scheduling insurance referral insur...
# 22016  manage outbound customer call investigate dete...
# 22017  perform data validation various client project...
# 22018  provide general administrative clerical suppor...
#
#                                    application_education  ...  \
# 580    High School Diploma++Mandatory courses++New Ha...  ...
# 688                                  High school diploma  ...
# 1047                                          12/diplona  ...
# 1480                                    Bachelor of Arts  ...
# 1901                                         High School  ...
# ...                                                  ...  ...
# 22014                       Bachelor's Degree in science  ...
# 22015                                            Diploma  ...
# 22016                              Bachelors++Associates  ...
# 22017                                        High School  ...
# 22018                   3 1/2 years++High School diploma  ...
#
#                                       application_skills  jaccard_similarity  \
# 580    [operations, increase sales, legal documents, ...            0.009709
# 688    [concrete, construction management, drainage, ...            0.000000
# 1047                                           [, floor]            0.000000
# 1480   [sales, sales manager, marketing, territory, t...            0.029940
# 1901                                    [, united state]            0.000000
# ...                                                  ...                 ...
# 22014  [laboratory, testing, documentation, healthcar...            0.020408
# 22015  [computer, acknowledging others, scheduling, i...            0.013158
# 22016  [microsoft office, interpersonal skills, multi...            0.030928
# 22017  [extensive experience in the customer support ...            0.000000
# 22018  [sales, billing, payments, sales executive, vo...            0.008772
#
#                                   intersected_skills intersected_skills_count  \
# 580                                      [operation]                        1
# 688                                               []                        0
# 1047                                              []                        0
# 1480          [industry, sale, access, plan, source]                        5
# 1901                                              []                        0
# ...                                              ...                      ...
# 22014  [receive, quality assurance, received, level]                        4
# 22015                             [customer service]                        1
# 22016        [customer service, data entry, account]                        3
# 22017                                             []                        0
# 22018                                   [data entry]                        1
#
#       application_reported_skills_list_length  \
# 580                                        21
# 688                                        14
# 1047                                        1
# 1480                                       45
# 1901                                        1
# ...                                       ...
# 22014                                      48
# 22015                                       9
# 22016                                      10
# 22017                                       1
# 22018                                      23
#
#       opportunity_required_skills_list_length  \
# 580                                        61
# 688                                        61
# 1047                                       61
# 1480                                       83
# 1901                                       61
# ...                                       ...
# 22014                                      64
# 22015                                      64
# 22016                                      64
# 22017                                      64
# 22018                                      64
#
#       brief_description_skills_list_length  \
# 580                                      5
# 688                                      5
# 1047                                     5
# 1480                                    10
# 1901                                     5
# ...                                    ...
# 22014                                    8
# 22015                                    8
# 22016                                    8
# 22017                                    8
# 22018                                    8
#
#        application_job_responsibilities_extracted_skills_list_length  \
# 580                                                   22
# 688                                                    8
# 1047                                                   1
# 1480                                                  44
# 1901                                                   1
# ...                                                  ...
# 22014                                                 88
# 22015                                                  4
# 22016                                                 26
# 22017                                                  7
# 22018                                                 28
#
#       application_skills_list_length  intersected_skills_list_length
# 580                               43                               1
# 688                               22                               0
# 1047                               2                               0
# 1480                              89                               5
# 1901                               2                               0
# ...                              ...                             ...
# 22014                            136                               4
# 22015                             13                               1
# 22016                             36                               3
# 22017                              8                               0
# 22018                             51                               1
#
# [73 rows x 26 columns]

# %%
aggregated_apps = pd.DataFrame(applications_sample.groupby("opportunity_id").agg(
    {"opportunity_description":"first", "opportunity_title":"first",  "application_job_responsibilities":list,})).reset_index()
aggregated_apps
# Out:
#              opportunity_id  \
# 0  +0cRKl9xvkGTQq4D8IwnAQ==
# 1  +3lu6kPHC06xU79BvlwHew==
# 2  +5os8/vB/EGBEahyGxRMjA==
# 3  7uXMjQV9r061ap/Lc91I1Q==
# 4  Im/cVgG09Uesn1fjkbt5TQ==
# 5  Pw9q3TmWDE6up1oUsv/OTA==
# 6  VPpkoLNRtUCOxpYUssltxg==
# 7  pJtXynDm6kqbyczn0dXkDg==
# 8  zsFZ88cMtUKMWf2kIKdncQ==
# 9  zu77vbq9g0ed54tWutsAig==
#
#                              opportunity_description  \
# 0  first year earnings opportunity 40 000 50 000 ...
# 1  orkin purpose help protect world live work pla...
# 2  orkin purpose help protect world live work pla...
# 3  orkin purpose help protect world live work pla...
# 4  orkin purpose help protect world live work pla...
# 5  orkin purpose help protect world live work pla...
# 6  19 00 per hour orkin purpose help protect worl...
# 7  orkin purpose help protect world live work pla...
# 8  15 00 per hour customer service specialist ful...
# 9  homepro subsidiary rollins inc nyse rol headqu...
#
#                               opportunity_title  \
# 0                      service technician train
# 1                  customer relation specialist
# 2                     outside sale professional
# 3  commercial sale representative hunter needed
# 4                     outside sale professional
# 5                            termite technician
# 6              service technician termite train
# 7                       pest control technician
# 8                   customer service specialist
# 9                      service technician train
#
#                     application_job_responsibilities
# 0  [removal stump removal tree chip brush clear d...
# 1  [support client engagement team cet customer e...
# 2  [national geographic snorkeler water sport equ...
# 3  [design develop implement national sale market...
# 4  [analyst business coaching consulting www righ...
# 5  [managed daily administrative operation depart...
# 6  [moved within company course several year orig...
# 7  [mix ink ship company use make drink can, resi...
# 8  [assist dealer support question incentive ship...
# 9  [supervised crew maintain lawn prune bush spra...

# %%
opportunity_titles = [aggregated_apps.iloc[n]["opportunity_title"] for n in range(len(aggregated_apps))]
opportunity_descriptions = [aggregated_apps.iloc[n]["opportunity_description"] for n in range(len(aggregated_apps))]

print(opportunity_titles)
print(opportunity_descriptions)
# Out:
# ['service technician train', 'customer relation specialist', 'outside sale professional', 'commercial sale representative hunter needed', 'outside sale professional', 'termite technician', 'service technician termite train', 'pest control technician', 'customer service specialist', 'service technician train']
# ['first year earnings opportunity 40 000 50 000 orkin purpose help protect world live work play orkin pest management industry leader offer extensive training service technician deliver valuable service customer every day interested chance expand knowledge grow career well financial opportunity check position turn much successful candidate complete award winning company paid training learn skill required responsible daily operation pest control service route follow route schedule within assigned territory ensuring timely safe arrival customer operate company vehicle safely ensure cleanliness vehicle equipment communicate customer ensure satisfaction discus additional service meet customer need complete pest management program serve problem solver customer utilizing depth training provided decide efficient best overall pest solution customer need complete required service related documentation leverage hand held device provided speed accuracy serve key member local branch team offer hellip competitive pay company vehicle upon route assignment comprehensive benefit package including medical dental vision maternity life insurance 401 k plan company match employee stock purchase plan paid vacation holiday sick leave employee discount tuition reimbursement dependent scholarship award industry leading quality comprehensive training program orkin founded 1901 orkin global residential business service provider provides accurate comprehensive efficient pest management service residential commercial customer industry leader value people progress professionalism pest management industry growing ndash recession resistant line business orkin financially stable growing largest subsidiary rollins inc nyse rol headquartered atlanta ga ready take career next level requirement require good driving record ability pas drug screen candidate must meet physical job requirement safely perform following job duty without accommodation safely use ladder within manufacturer weight capacity lift carry 50 lb safely access crawl space attic confined space roof top etc ability work type weather condition', 'orkin purpose help protect world live work play customer service specialist committed purpose customer service specialist full time benefit fully paid training competitive wage opportunity career growth orkin provide accurate comprehensive efficient pest management service residential commercial customer position ideal candidate want part rock solid company providing valuable service customer growing career successful customer service specialist demonstrate strong work ethic capacity handle high work volume great teamwork environment contact customer schedule confirm service appointment schedule appointment technician minimize drive time distance needed suggest alternative route appropriate schedule communicate service technician meet customer requirement perform outbound call customer follow service received perform outbound call customer regarding outstanding account balance receive payment past due customer proficiently navigate window based web based system track route optimize current future schedule reschedule unserviced account within 24 hour answer inbound customer service call open friendly greeting utilize strong listening skill probing question identify customer rsquo concern evaluate need use strong communication skill communicate empathize customer work well within team participate quality assurance process program initiative requested organized efficient accurate accountable strong ability multi task consider key role part branch team offer hellip competitive hourly pay comprehensive benefit package including medical dental vision maternity life insurance 401 k plan company match employee stock purchase plan paid vacation holiday sick leave employee discount tuition reimbursement dependent scholarship award quality comprehensive training program orkin founded 1901 orkin global residential business service provider provides accurate comprehen ...

# %%
outputs = []

for n in range(0, len(aggregated_apps)):
    opportunity_title = opportunity_titles[n]
    opportunity_description = opportunity_descriptions[n]
    _input = prompt.format_prompt(opportunity_title=opportunity_title, opportunity_description=opportunity_description)

    #print (f"There are {len(_input.messages)} message(s)")
    #print (f"Type: {type(_input.messages[0])}")
    #print ("---------------------------")
    #print (_input.messages[0].content)
    output = chat_model(_input.to_messages())
    outputs.append(output)
aggregated_apps['gpt_generated_skill_list'] = outputs

# %%
aggregated_apps['gpt_generated_skill_list_content'] = aggregated_apps['gpt_generated_skill_list'].apply(lambda x: x.content)
#Remove the ```json\n[\n\t{\n\t\t"opportunity_skills": """ and """\n\t}\n]\n``` from the output
aggregated_apps['gpt_generated_skill_list_content'] = aggregated_apps['gpt_generated_skill_list_content'].apply(lambda x: x.replace('```json\n[\n\t{\n\t\t"opportunity_skills":', ''))
# I only want what is in double quotes from the gpt_generated_skill_list_content column
aggregated_apps['gpt_generated_skill_list_content'] = aggregated_apps['gpt_generated_skill_list_content'].apply(lambda x: x.split('"')[1::2])
aggregated_apps['gpt_generated_skill_list_content']
# Out:
# 0    [extensive training, service delivery, custome...
# 1    [customer service, strong work ethic, teamwork...
# 2    [outside sales, customer service, problem solv...
# 3    [hunter mentality, sales experience, prospecti...
# 4    [outside sales, customer service, problem-solv...
# 5    [pest control, customer service, problem solvi...
# 6    [termite technician, pest control, customer se...
# 7    [pest control, customer service, problem solvi...
# 8    [customer service, communication, teamwork, wo...
# 9    [service technician, training, customer servic...
# Name: gpt_generated_skill_list_content, dtype: object

# %%
aggregated_apps
# Out:
#              opportunity_id  \
# 0  +0cRKl9xvkGTQq4D8IwnAQ==
# 1  +3lu6kPHC06xU79BvlwHew==
# 2  +5os8/vB/EGBEahyGxRMjA==
# 3  7uXMjQV9r061ap/Lc91I1Q==
# 4  Im/cVgG09Uesn1fjkbt5TQ==
# 5  Pw9q3TmWDE6up1oUsv/OTA==
# 6  VPpkoLNRtUCOxpYUssltxg==
# 7  pJtXynDm6kqbyczn0dXkDg==
# 8  zsFZ88cMtUKMWf2kIKdncQ==
# 9  zu77vbq9g0ed54tWutsAig==
#
#                              opportunity_description  \
# 0  first year earnings opportunity 40 000 50 000 ...
# 1  orkin purpose help protect world live work pla...
# 2  orkin purpose help protect world live work pla...
# 3  orkin purpose help protect world live work pla...
# 4  orkin purpose help protect world live work pla...
# 5  orkin purpose help protect world live work pla...
# 6  19 00 per hour orkin purpose help protect worl...
# 7  orkin purpose help protect world live work pla...
# 8  15 00 per hour customer service specialist ful...
# 9  homepro subsidiary rollins inc nyse rol headqu...
#
#                               opportunity_title  \
# 0                      service technician train
# 1                  customer relation specialist
# 2                     outside sale professional
# 3  commercial sale representative hunter needed
# 4                     outside sale professional
# 5                            termite technician
# 6              service technician termite train
# 7                       pest control technician
# 8                   customer service specialist
# 9                      service technician train
#
#                     application_job_responsibilities  \
# 0  [removal stump removal tree chip brush clear d...
# 1  [support client engagement team cet customer e...
# 2  [national geographic snorkeler water sport equ...
# 3  [design develop implement national sale market...
# 4  [analyst business coaching consulting www righ...
# 5  [managed daily administrative operation depart...
# 6  [moved within company course several year orig...
# 7  [mix ink ship company use make drink can, resi...
# 8  [assist dealer support question incentive ship...
# 9  [supervised crew maintain lawn prune bush spra...
#
#                             gpt_generated_skill_list  \
# 0  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 1  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 2  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 3  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 4  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 5  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 6  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 7  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 8  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 9  content='```json\n[\n\t{\n\t\t"opportunity_ski...
#
#                     gpt_generated_skill_list_content
# 0  [extensive training, service delivery, custome...
# 1  [customer service, strong work ethic, teamwork...
# 2  [outside sales, customer service, problem solv...
# 3  [hunter mentality, sales experience, prospecti...
# 4  [outside sales, customer service, problem-solv...
# 5  [pest control, customer service, problem solvi...
# 6  [termite technician, pest control, customer se...
# 7  [pest control, customer service, problem solvi...
# 8  [customer service, communication, teamwork, wo...
# 9  [service technician, training, customer servic...

# %% [markdown]
# ### Do the same with the applications.

# %%
# How you would like your response structured. This is basically a fancy prompt template
response_schemas = [
    ResponseSchema(name="applicant_skills",
    description="These are the hard and soft skills you extract from the applicants' background"),
]

# How you would like to parse your output
output_parser = StructuredOutputParser.from_response_schemas(response_schemas)

# %%
# See the prompt template you created for formatting
format_instructions = output_parser.get_format_instructions()
print (output_parser.get_format_instructions())
# Out:
# The output should be a markdown code snippet formatted in the following schema, including the leading and trailing "```json" and "```":
#
# ```json
# {
# 	"applicant_skills": string  // These are the hard and soft skills you extract from the applicants' background
# }
# ```

# %%
template = """
You will be given a job applicants' background.
Your job is to extract soft and hard skills from the job description.

{format_instructions}

Wrap your final output with closed and open brackets (a list of json objects)

input_opportunity_description INPUT:
{applicant_background}

YOUR RESPONSE:
"""

prompt = ChatPromptTemplate(
    messages=[
        HumanMessagePromptTemplate.from_template(template)  
    ],
    input_variables=["applicant_background"],
    partial_variables={"format_instructions": format_instructions}
)

# %%
list_of_applicants_experiences = applications_sample.application_job_responsibilities.to_list()

# %%
outputs = []

for experiences in list_of_applicants_experiences:
    if experiences == None:
        experiences = "None"
    _input = prompt.format_prompt(applicant_background=experiences)

    #print (f"There are {len(_input.messages)} message(s)")
    #print (f"Type: {type(_input.messages[0])}")
    #print ("---------------------------")
    #print (_input.messages[0].content)
    output = chat_model(_input.to_messages())
    outputs.append(output)
applications_sample['application_skills_gpt_extraction'] = outputs
# Out:
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/4131403485.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   applications_sample['application_skills_gpt_extraction'] = outputs

# %%
applications_sample.head(2)
# Out:
#                opportunity_id            application_id  \
# 580  Pw9q3TmWDE6up1oUsv/OTA==  jiJ1JAa/AkWkg853IcV99A==
# 688  Pw9q3TmWDE6up1oUsv/OTA==  DMMShh6ksEeTDMTqbqS5Nw==
#
#                          opportunity_brief_description  \
# 580  orkin purpose help protect world live work pla...
# 688  orkin purpose help protect world live work pla...
#
#                                opportunity_description   opportunity_title  \
# 580  orkin purpose help protect world live work pla...  termite technician
# 688  orkin purpose help protect world live work pla...  termite technician
#
#     application_pass_first_step application_step_category  \
# 580                       False                         0
# 688                       False                         0
#
#                                 application_job_titles  \
# 580  detention officer order builder administrative...
# 688           construction superintendent part manager
#
#                       application_job_responsibilities  \
# 580  managed daily administrative operation departm...
# 688  osha 10 30 hour certification 15 year general ...
#
#                                  application_education  ...  \
# 580  High School Diploma++Mandatory courses++New Ha...  ...
# 688                                High school diploma  ...
#
#     jaccard_similarity  intersected_skills  intersected_skills_count  \
# 580           0.009709         [operation]                         1
# 688           0.000000                  []                         0
#
#     application_reported_skills_list_length  \
# 580                                      21
# 688                                      14
#
#     opportunity_required_skills_list_length  \
# 580                                      61
# 688                                      61
#
#     brief_description_skills_list_length  \
# 580                                    5
# 688                                    5
#
#     application_job_responsibilities_extracted_skills_list_length  \
# 580                                                 22
# 688                                                  8
#
#      application_skills_list_length intersected_skills_list_length  \
# 580                              43                              1
# 688                              22                              0
#
#                      application_skills_gpt_extraction
# 580  content='```json\n[\n\t{\n\t\t"applicant_skill...
# 688  content='```json\n[\n\t{\n\t\t"applicant_skill...
#
# [2 rows x 27 columns]

# %%
applications_sample['application_skills_gpt_extraction'].iloc[0].content
# Out:
# '```json\n[\n\t{\n\t\t"applicant_skills": "administrative operations, phone call handling, data entry, inmate management, safety and security enforcement, inventory management, warehouse operations, forklift driving, quality control, training, document processing, transcribing, client communication"\n\t}\n]\n```'

# %%
applications_sample['application_skills_gpt_extraction_content'] = applications_sample['application_skills_gpt_extraction'].apply(lambda x: x.content)
#applications_sample['application_skills_gpt_extraction_content'] = applications_sample['application_skills_gpt_extraction_content'].apply(lambda x: x.replace('```json\n[\n\t{\n\t\t"opportunity_skills":', ''))
applications_sample['application_skills_gpt_extraction_content'] = applications_sample['application_skills_gpt_extraction_content'].apply(lambda x: x.split('"')[1::2])
applications_sample['application_skills_gpt_extraction_content']
# Out:
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/659586493.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   applications_sample['application_skills_gpt_extraction_content'] = applications_sample['application_skills_gpt_extraction'].apply(lambda x: x.content)
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/659586493.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   applications_sample['application_skills_gpt_extraction_content'] = applications_sample['application_skills_gpt_extraction_content'].apply(lambda x: x.split('"')[1::2])
# 580      [applicant_skills, administrative operations, ...
# 688      [applicant_skills, osha 10 30 hour certificati...
# 1047                 [applicant_skills, floor maintenance]
# 1480     [applicant_skills, design, develop, implement,...
# 1901     [applicant_skills, completed 4 year contract, ...
#                                ...
# 22014    [applicant_skills, release product, product ho...
# 22015    [applicant_skills, accounting, scheduling, ins...
# 22016    [applicant_skills, customer service, data entr...
# 22017    [applicant_skills, data validation, client pro...
# 22018    [applicant_skills, general administrative cler...
# Name: application_skills_gpt_extraction_content, Length: 73, dtype: object

# %%
applications_sample = applications_sample.merge(aggregated_apps[['opportunity_id', 'gpt_generated_skill_list_content']], on='opportunity_id', how='left')
applications_sample
# Out:
#               opportunity_id            application_id  \
# 0   Pw9q3TmWDE6up1oUsv/OTA==  jiJ1JAa/AkWkg853IcV99A==
# 1   Pw9q3TmWDE6up1oUsv/OTA==  DMMShh6ksEeTDMTqbqS5Nw==
# 2   Pw9q3TmWDE6up1oUsv/OTA==  UUO4CGKds0SR5OdxnONVag==
# 3   7uXMjQV9r061ap/Lc91I1Q==  i2GfHI8PiE2iSfMDmjNh3Q==
# 4   Pw9q3TmWDE6up1oUsv/OTA==  wuHbCd1jAkSVhHG44qUcBg==
# ..                       ...                       ...
# 68  +3lu6kPHC06xU79BvlwHew==  o9zE84ts7EeTJ16L/Et5AQ==
# 69  +3lu6kPHC06xU79BvlwHew==  VinkkPxps0ulKfwNA9qOeQ==
# 70  +3lu6kPHC06xU79BvlwHew==  PN7h+ikMHEKaJ/lKkTOYjg==
# 71  +3lu6kPHC06xU79BvlwHew==  58O63nAFEkSn6PEFm63C4g==
# 72  +3lu6kPHC06xU79BvlwHew==  ogoMXwf8hkKmTzUBjfLFgA==
#
#                         opportunity_brief_description  \
# 0   orkin purpose help protect world live work pla...
# 1   orkin purpose help protect world live work pla...
# 2   orkin purpose help protect world live work pla...
# 3   orkin purpose help protect world live work pla...
# 4   orkin purpose help protect world live work pla...
# ..                                                ...
# 68  orkin purpose help protect world live work pla...
# 69  orkin purpose help protect world live work pla...
# 70  orkin purpose help protect world live work pla...
# 71  orkin purpose help protect world live work pla...
# 72  orkin purpose help protect world live work pla...
#
#                             opportunity_description_x  \
# 0   orkin purpose help protect world live work pla...
# 1   orkin purpose help protect world live work pla...
# 2   orkin purpose help protect world live work pla...
# 3   orkin purpose help protect world live work pla...
# 4   orkin purpose help protect world live work pla...
# ..                                                ...
# 68  orkin purpose help protect world live work pla...
# 69  orkin purpose help protect world live work pla...
# 70  orkin purpose help protect world live work pla...
# 71  orkin purpose help protect world live work pla...
# 72  orkin purpose help protect world live work pla...
#
#                              opportunity_title_x application_pass_first_step  \
# 0                             termite technician                       False
# 1                             termite technician                       False
# 2                             termite technician                        True
# 3   commercial sale representative hunter needed                        True
# 4                             termite technician                       False
# ..                                           ...                         ...
# 68                  customer relation specialist                       False
# 69                  customer relation specialist                       False
# 70                  customer relation specialist                       False
# 71                  customer relation specialist                       False
# 72                  customer relation specialist                       False
#
#    application_step_category  \
# 0                          0
# 1                          0
# 2                          0
# 3                          0
# 4                          0
# ..                       ...
# 68                         0
# 69                         0
# 70                         0
# 71                         0
# 72                         0
#
#                                application_job_titles  \
# 0   detention officer order builder administrative...
# 1            construction superintendent part manager
# 2                                             laborer
# 3   president bdm sale manager area sale manager t...
# 4                         threat reduction specialist
# ..                                                ...
# 68  quality control technician laboratory technici...
# 69                                            manager
# 70  fraud detection coordinator assistant manager ...
# 71                         compliance service analyst
# 72  office assistant inbound sale executive telema...
#
#                    application_job_responsibilities_x  \
# 0   managed daily administrative operation departm...
# 1   osha 10 30 hour certification 15 year general ...
# 2                         currently floor maintenance
# 3   design develop implement national sale marketi...
# 4   completed 4 year contract united state marine ...
# ..                                                ...
# 68  perform release product product hold analysis ...
# 69  accounting scheduling insurance referral insur...
# 70  manage outbound customer call investigate dete...
# 71  perform data validation various client project...
# 72  provide general administrative clerical suppor...
#
#                                 application_education  ...  \
# 0   High School Diploma++Mandatory courses++New Ha...  ...
# 1                                 High school diploma  ...
# 2                                          12/diplona  ...
# 3                                    Bachelor of Arts  ...
# 4                                         High School  ...
# ..                                                ...  ...
# 68                       Bachelor's Degree in science  ...
# 69                                            Diploma  ...
# 70                              Bachelors++Associates  ...
# 71                                        High School  ...
# 72                   3 1/2 years++High School diploma  ...
#
#    application_skills_list_length  intersected_skills_list_length  \
# 0                              43                               1
# 1                              22                               0
# 2                               2                               0
# 3                              89                               5
# 4                               2                               0
# ..                            ...                             ...
# 68                            136                               4
# 69                             13                               1
# 70                             36                               3
# 71                              8                               0
# 72                             51                               1
#
#                     application_skills_gpt_extraction  \
# 0   content='```json\n[\n\t{\n\t\t"applicant_skill...
# 1   content='```json\n[\n\t{\n\t\t"applicant_skill...
# 2   content='```json\n[\n\t{\n\t\t"applicant_skill...
# 3   content='```json\n[\n\t{\n\t\t"applicant_skill...
# 4   content='```json\n[\n\t{\n\t\t"applicant_skill...
# ..                                                ...
# 68  content='```json\n[\n\t{\n\t\t"applicant_skill...
# 69  content='```json\n[\n\t{\n\t\t"applicant_skill...
# 70  content='```json\n[\n\t{\n\t\t"applicant_skill...
# 71  content='```json\n[\n\t{\n\t\t"applicant_skill...
# 72  content='```json\n[\n\t{\n\t\t"applicant_skill...
#
#             application_skills_gpt_extraction_content  \
# 0   [applicant_skills, administrative operations, ...
# 1   [applicant_skills, osha 10 30 hour certificati...
# 2               [applicant_skills, floor maintenance]
# 3   [applicant_skills, design, develop, implement,...
# 4   [applicant_skills, completed 4 year contract, ...
# ..                                                ...
# 68  [applicant_skills, release product, product ho...
# 69  [applicant_skills, accounting, scheduling, ins...
# 70  [applicant_skills, customer service, data entr...
# 71  [applicant_skills, data validation, client pro...
# 72  [applicant_skills, general administrative cler...
#
#                             opportunity_description_y  \
# 0   orkin purpose help protect world live work pla...
# 1   orkin purpose help protect world live work pla...
# 2   orkin purpose help protect world live work pla...
# 3   orkin purpose help protect world live work pla...
# 4   orkin purpose help protect world live work pla...
# ..                                                ...
# 68  orkin purpose help protect world live work pla...
# 69  orkin purpose help protect world live work pla...
# 70  orkin purpose help protect world live work pla...
# 71  orkin purpose help protect world live work pla...
# 72  orkin purpose help protect world live work pla...
#
#                              opportunity_title_y  \
# 0                             termite technician
# 1                             termite technician
# 2                             termite technician
# 3   commercial sale representative hunter needed
# 4                             termite technician
# ..                                           ...
# 68                  customer relation specialist
# 69                  customer relation specialist
# 70                  customer relation specialist
# 71                  customer relation specialist
# 72                  customer relation specialist
#
#                    application_job_responsibilities_y  \
# 0   [managed daily administrative operation depart...
# 1   [managed daily administrative operation depart...
# 2   [managed daily administrative operation depart...
# 3   [design develop implement national sale market...
# 4   [managed daily administrative operation depart...
# ..                                                ...
# 68  [support client engagement team cet customer e...
# 69  [support client engagement team cet customer e...
# 70  [support client engagement team cet customer e...
# 71  [support client engagement team cet customer e...
# 72  [support client engagement team cet customer e...
#
#                              gpt_generated_skill_list  \
# 0   content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 1   content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 2   content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 3   content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 4   content='```json\n[\n\t{\n\t\t"opportunity_ski...
# ..                                                ...
# 68  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 69  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 70  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 71  content='```json\n[\n\t{\n\t\t"opportunity_ski...
# 72  content='```json\n[\n\t{\n\t\t"opportunity_ski...
#
#                    gpt_generated_skill_list_content_x  \
# 0   [pest control, customer service, problem solvi...
# 1   [pest control, customer service, problem solvi...
# 2   [pest control, customer service, problem solvi...
# 3   [hunter mentality, sales experience, prospecti...
# 4   [pest control, customer service, problem solvi...
# ..                                                ...
# 68  [customer service, strong work ethic, teamwork...
# 69  [customer service, strong work ethic, teamwork...
# 70  [customer service, strong work ethic, teamwork...
# 71  [customer service, strong work ethic, teamwork...
# 72  [customer service, strong work ethic, teamwork...
#
#                    gpt_generated_skill_list_content_y
# 0   [pest control, customer service, problem solvi...
# 1   [pest control, customer service, problem solvi...
# 2   [pest control, customer service, problem solvi...
# 3   [hunter mentality, sales experience, prospecti...
# 4   [pest control, customer service, problem solvi...
# ..                                                ...
# 68  [customer service, strong work ethic, teamwork...
# 69  [customer service, strong work ethic, teamwork...
# 70  [customer service, strong work ethic, teamwork...
# 71  [customer service, strong work ethic, teamwork...
# 72  [customer service, strong work ethic, teamwork...
#
# [73 rows x 34 columns]

# %%
skill_lists = applications_sample[['gpt_generated_skill_list_content', 'application_skills_gpt_extraction_content']]
skill_lists.columns = ['opportunity_skills', 'applicant_skills']


#make the lists of skills into sets
skill_lists['opportunity_skills'] = skill_lists['opportunity_skills'].apply(lambda x: set(x))
skill_lists['applicant_skills'] = skill_lists['applicant_skills'].apply(lambda x: [i for i in x if i != 'applicant_skills'])
skill_lists['applicant_skills'] = skill_lists['applicant_skills'].apply(lambda x: set(x))
# Out:
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/3910910033.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skill_lists['opportunity_skills'] = skill_lists['opportunity_skills'].apply(lambda x: set(x))
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/3910910033.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skill_lists['applicant_skills'] = skill_lists['applicant_skills'].apply(lambda x: [i for i in x if i != 'applicant_skills'])
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/3910910033.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skill_lists['applicant_skills'] = skill_lists['applicant_skills'].apply(lambda x: set(x))

# %%
applications_sample.columns
# Out:
# Index(['opportunity_id', 'application_id', 'opportunity_brief_description',
#        'opportunity_description_x', 'opportunity_title_x',
#        'application_pass_first_step', 'application_step_category',
#        'application_job_titles', 'application_job_responsibilities_x',
#        'application_education', 'application_reported_skills',
#        'similarity_score', 'similarity_rank', 'opportunity_required_skills',
#        'brief_description_skills',
#        'application_job_responsibilities_extracted_skills',
#        'application_skills', 'jaccard_similarity', 'intersected_skills',
#        'intersected_skills_count', 'application_reported_skills_list_length',
#        'opportunity_required_skills_list_length',
#        'brief_description_skills_list_length',
#        'application_job_responsibilities_extracted_skills_list_length',
#        'application_skills_list_length', 'intersected_skills_list_length',
#        'application_skills_gpt_extraction',
#        'application_skills_gpt_extraction_content',
#        'opportunity_description_y', 'opportunity_title_y',
#        'application_job_responsibilities_y', 'gpt_generated_skill_list',
#        'gpt_generated_skill_list_content_x',
#        'gpt_generated_skill_list_content_y'],
#       dtype='object')

# %%
gpt_generated_skills = applications_sample[['opportunity_id', 'opportunity_title_x', 'opportunity_description_x', 'application_id', 'application_job_responsibilities_x', 'gpt_generated_skill_list_content_x', 'application_skills_gpt_extraction_content', 'opportunity_required_skills', 'application_job_responsibilities_extracted_skills',]]
gpt_generated_skills.columns = ['opportunity_id', 'opportunity_title', 'opportunity_description', 'application_id', 'application_job_responsibilities', 'opportunity_skills_gpt', 'applicant_skills_gpt', 'opportunity_skills_skillNER', 'applicant_skills_skillNER']
gpt_generated_skills.sample(4)
# Out:
#               opportunity_id         opportunity_title  \
# 28  Pw9q3TmWDE6up1oUsv/OTA==        termite technician
# 57  zu77vbq9g0ed54tWutsAig==  service technician train
# 42  Pw9q3TmWDE6up1oUsv/OTA==        termite technician
# 38  Pw9q3TmWDE6up1oUsv/OTA==        termite technician
#
#                               opportunity_description  \
# 28  orkin purpose help protect world live work pla...
# 57  homepro subsidiary rollins inc nyse rol headqu...
# 42  orkin purpose help protect world live work pla...
# 38  orkin purpose help protect world live work pla...
#
#               application_id  \
# 28  nDEHCuGVvkueDM8cv744ag==
# 57  hxgj2IzWOUOtWWfMHhd7Ig==
# 42  1Kd9yok5L0GCmCWFefPM9w==
# 38  uNuvh//qHkm+jYrkzSsXuQ==
#
#                      application_job_responsibilities  \
# 28  responsible prepping food item busy night week...
# 57  secures premise personnel patrolling property ...
# 42  name triston roseman currently serving united ...
# 38  november 2017 present electrical aptitude test...
#
#                                opportunity_skills_gpt  \
# 28  [pest control, customer service, problem solvi...
# 57  [service technician, training, customer servic...
# 42  [pest control, customer service, problem solvi...
# 38  [pest control, customer service, problem solvi...
#
#                                  applicant_skills_gpt  \
# 28  [applicant_skills, prepping food, stocking kit...
# 57  [applicant_skills, security, premises, personn...
# 42                    [applicant_skills, hardworking]
# 38  [applicant_skills, electrical aptitude, troubl...
#
#                           opportunity_skills_skillNER  \
# 28  [pest control, service provider, good driving ...
# 57  [pest control, good driving record, career man...
# 42  [pest control, service provider, good driving ...
# 38  [pest control, service provider, good driving ...
#
#                             applicant_skills_skillNER
# 28  [social skill, food, food, communicated, prepa...
# 57                                       [patrolling]
# 42                                     [united state]
# 38  [customer service, corrosion control, personal...

# %%
gpt_generated_skills.to_pickle("../../Data/gpt_generated_skills.pkl")

# %%
skill_lists['jaccard_similarity'] = skill_lists.apply(lambda x: len(x['opportunity_skills'].intersection(x['applicant_skills'])) / len(x['opportunity_skills'].union(x['applicant_skills'])), axis=1)
# Out:
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/3983371153.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skill_lists['jaccard_similarity'] = skill_lists.apply(lambda x: len(x['opportunity_skills'].intersection(x['applicant_skills'])) / len(x['opportunity_skills'].union(x['applicant_skills'])), axis=1)

# %%
skill_lists['jaccard_similarity'].describe()
# Out:
# count    73.0
# mean      0.0
# std       0.0
# min       0.0
# 25%       0.0
# 50%       0.0
# 75%       0.0
# max       0.0
# Name: jaccard_similarity, dtype: float64

# %%
skill_lists['intersection'] = skill_lists.apply(lambda x: x['opportunity_skills'].intersection(x['applicant_skills']), axis=1)
# Out:
# /var/folders/1w/3dbsn3055ss61n_2tk2w2crm0000gn/T/ipykernel_28424/4123289419.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   skill_lists['intersection'] = skill_lists.apply(lambda x: x['opportunity_skills'].intersection(x['applicant_skills']), axis=1)

# %%
skill_lists['intersection'].describe()
# Out:
# count     73
# unique     1
# top       {}
# freq      73
# Name: intersection, dtype: object

# %% [markdown]
# ### When GPT Generated the skills given the applications and the job descriptions, it did not generate any skills that were in the job description in any case.
